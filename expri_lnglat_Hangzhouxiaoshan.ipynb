# %%
# 本文件的主要目的是看能否把地址信息转录成良好的格式，供地址解析API解析成坐标点
import pandas as pd
import numpy as np

df = pd.read_csv( 'proced_hangzhou.csv', index_col=0, parse_dates=['startTime', 'stopTime', 'duration'])

# %%
df.loc[:, ['scope', 'duration']]
# Out:
#                                                    scope  \
# 0      浙江省-杭州市-富阳区-东洲街道(杭州富阳区东洲街道小铭建筑材料经营部,杭州富阳宏运金属压延...
# 1                  浙江省-杭州市-余杭区-良渚街道-杭州艺旺包装材料有限公司、良渚博物院一带
# 2      浙江省-杭州市-富阳区-新登镇-昌东行政村-昌东自然村,新登镇-松溪行政村(松溪家园自然村,...
# 3                    浙江省-杭州市-余杭区-乔司街道-方桥行政村(目野自然村,方桥自然村)
# 4             浙江省-杭州市-富阳区-银湖街道(高桥行政村-舒姑垟自然村,郜村行政村-郜村自然村)
# ...                                                  ...
# 17784                 浙江省-杭州市-桐庐县-城南街道-桑园行政村(梅林路,桑园里自然村)
# 17785  浙江省-杭州市-西湖区-灵隐街道-浙大求是社区-浙大路求是村19幢、20幢、34幢、46幢、...
# 17786                        浙江省-杭州市-桐庐县-横村镇-龙伏行政村-龙伏自然村
# 17787  浙江省-杭州市-临安市-青山湖街道-庆北行政村-临北自然村,青山湖街道-孝村行政村(窑田畈自...
# 17788  浙江省-杭州市-临安市-於潜镇-朱湾行政村(朱湾自然村,西桥自然村,东平自然村),於潜镇-杨...
#
#                         duration
# 0      0 days 01:46:00.000000000
# 1      0 days 02:41:00.000000000
# 2      0 days 00:40:36.000000000
# 3      0 days 01:50:00.000000000
# 4      0 days 00:58:34.000000000
# ...                          ...
# 17784  0 days 02:00:00.000000000
# 17785  0 days 05:00:00.000000000
# 17786  0 days 02:00:00.000000000
# 17787  0 days 02:00:00.000000000
# 17788  0 days 01:25:00.000000000
#
# [15803 rows x 2 columns]

# %%
# 那我们的思路是，先用某种方法分割地址，因为一个停电事件可能对应到多个不同的点；这样一个停电事故的scope就变成了：(scope: [ p1, p2, .. px ]) 这么一个点列表
# 然后是将同一个scope里的点进行相近合并。 定制规则，让同一条事件中相近的点合并成为一个点

# 最后我们会得到一张格点图，每个格点有它的停电时长的值，当然还有历史值，即某次x长时间的停电距今多久了；然后对此进行建模

# 这里我们先试图绘制热力图，筛出一个区来绘制吧，比如萧山区
xsdf = df[df.scope.str.contains("萧山区")]

# %%
xsdf = xsdf.reset_index().drop('index', axis=1)
xsdf
# Out:
#             poweroffId     lineName  \
# 0     2019102031020050  10kV单家C167线
# 1     2019102031020016   10kV新创502线
# 2     2019101931020150  10kV港城A815线
# 3     2019101931020109  10kV惠围A128线
# 4     2019101931020079  10kV国航C147线
# ...                ...          ...
# 2835  2020052631020255  10kV大同C235线
# 2836  2020052631020137  10kV树蓬A530线
# 2837  2020061331020031  10kV北南A120线
# 2838  2020061331020005  10kV山三A144线
# 2839  2020061231020881  10kV霞飞C224线
#
#                                             pubTranName  \
# 0                                              罗幕村14#变,
# 1                                               闸北村7#变,
# 2     南兴村18#变,岩峰村5#变,岩峰村1#变,岩峰村3#变,岩峰村17#变,岩峰村11#变,南...
# 3                                             顺丰家园4#公变,
# 4                           杭州煜辉活塞销厂,杭州公安局萧山分局,花神庙村5#变,
# ...                                                 ...
# 2835                                          大同三村12#变,
# 2836                                            安家山2#变,
# 2837                                         长龙领航城7#公变,
# 2838  杭州新丝路布业有限公司,长联村16#变,1#变,杭州美兰卫浴洁具有限公司,杭州新丝路布业有限...
# 2839                                            付娄村5#变,
#
#                                                   scope           startTime  \
# 0     浙江省-杭州市-萧山区-义桥镇-罗幕行政村-王家桥自然村、浙江省杭州市萧山区义桥镇王家桥农贸... 2019-10-20 09:50:16
# 1          浙江省-杭州市-萧山区-河庄街道-闸北行政村-闸北自然村、河庄街道闸北村、闸北行政村一带 2019-10-20 07:14:18
# 2     浙江省-杭州市-萧山区-南阳街道-南兴行政村(南北自然村,南兴自然村,南联自然村),南阳街道... 2019-10-19 15:40:46
# 3      浙江省-杭州市-萧山区-宁围镇-宁围街道-丰东行政村-文明路、顺丰家园小区、顺丰家园24幢等一带 2019-10-19 14:15:23
# 4     浙江省-杭州市-萧山区-靖江街道-花神庙社区-花神庙自然村;靖江街道-花神庙社区(杭州市公安... 2019-10-19 13:00:34
# ...                                                 ...                 ...
# 2835                     浙江省-杭州市-萧山区-楼塔镇-大同三行政村-大同坞自然村等 2020-05-26 15:30:38
# 2836                       浙江省-杭州市-萧山区-浦阳镇-桃源行政村-闸上自然村等 2020-05-26 11:23:04
# 2837                        浙江省-杭州市-萧山区-北干街道-信息港社区-建设四路 2020-06-13 06:46:00
# 2838  浙江省-杭州市-萧山区-瓜沥镇-长联行政村(长沙路,长沙自然村),瓜沥镇-解放行政村(解放自... 2020-06-13 01:56:00
# 2839  浙江省-杭州市-萧山区-新塘街道-傅楼行政村(傅家畈自然村,河南娄自然村,河北楼自然村)，新... 2020-06-12 21:24:00
#
#      typeCode                     poweroffArea  \
# 0     电网故障停限电   110kV许贤变:单家C167线-罗幕村14#变台区低压开关
# 1     电网故障停限电      35kV永丰变:新创502线-闸北村7#变台区低压开关
# 2     电网故障停限电     110kV黎明变:港城A815线-河蓬A8152开关后段
# 3     电网故障停限电  110kV惠兴变:惠围A128线-顺丰家园4#公变台区低压开关
# 4     电网故障停限电          110kV梅西变:国航C147线-公安分线后段
# ...       ...                              ...
# 2835  电网故障停限电     35kV楼塔变:大同C235线-大同三村12#变低压开关
# 2836  电网故障停限电      110kV浦阳变:树蓬A530线-安家山2#变低压开关
# 2837  电网故障停限电      110kV惠兴变:北南A120线长龙领航城7#公变配变
# 2838  电网故障停限电      220kV甘露变:山三A144线山三A1443开关后段
# 2839  电网故障停限电           110kV霞江变:霞飞C224线付娄村5#变
#
#                                          poweroffReason            powerTime  \
# 0                                        (低压停电信息)低压开关跳闸  2019-10-20 11:19:34
# 1                                        (低压停电信息)低压开关跳闸  2019-10-20 10:48:49
# 2     高压柱上断路器短路故障 原停电结束时间:2019-10-19 23:58:46,变更停电结束...  2019-10-19 19:02:56
# 3                                   （低压停电信息）低压漏电保护器短路故障  2019-10-19 15:02:52
# 4     高压柱上断路器短路故障 原停电结束时间: 2019-10-19 17:00:34，变更停电结...  2019-10-19 15:42:04
# ...                                                 ...                  ...
# 2835                                  (低压停电信息)低压漏电保护器跳闸  2020-05-26 16:15:02
# 2836                                  (低压停电信息)低压漏电保护器跳闸  2020-05-26 12:22:03
# 2837                                             高压开关跳闸  2020-06-13 07:48:38
# 2838  高压开关跳闸 原停电结束时间为2020-06-13 07:56:00,为减少客户停电时间,加...  2020-06-13 03:43:43
# 2839  油浸式变压器故障 变更停电地理区域和停电结束时间和停电原因原停电结束时间为2020-06-1...  2020-06-12 23:42:27
#
#       cityCode          cityName            stopTime  \
# 0      3340130  国网浙江杭州市萧山区供电有限公司 2019-10-20 12:00:16
# 1      3340120   国网浙江杭州市钱塘新区供电公司 2019-10-20 11:40:18
# 2      3340130  国网浙江杭州市萧山区供电有限公司 2019-10-19 19:45:46
# 3      3340130  国网浙江杭州市萧山区供电有限公司 2019-10-19 15:54:23
# 4      3340130  国网浙江杭州市萧山区供电有限公司 2019-10-19 16:35:34
# ...        ...               ...                 ...
# 2835   3340130  国网浙江杭州市萧山区供电有限公司 2020-05-26 16:45:38
# 2836   3340130  国网浙江杭州市萧山区供电有限公司 2020-05-26 12:55:04
# 2837   3340130  国网浙江杭州市萧山区供电有限公司 2020-06-13 08:46:00
# 2838   3340130  国网浙江杭州市萧山区供电有限公司 2020-06-13 04:30:00
# 2839   3340130  国网浙江杭州市萧山区供电有限公司 2020-06-13 00:30:00
#
#                        duration
# 0     0 days 02:10:00.000000000
# 1     0 days 04:26:00.000000000
# 2     0 days 04:05:00.000000000
# 3     0 days 01:39:00.000000000
# 4     0 days 03:35:00.000000000
# ...                         ...
# 2835  0 days 01:15:00.000000000
# 2836  0 days 01:32:00.000000000
# 2837  0 days 02:00:00.000000000
# 2838  0 days 02:34:00.000000000
# 2839  0 days 03:06:00.000000000
#
# [2840 rows x 13 columns]

# %%
# 我们处理scope字符串的策略是，先去掉前缀，然后多点分割，最后集体用地图api解析， 写入字典，再放回去。

# 先看能不能去掉共同的 省市区前缀, 看看有无是不以这个为前缀的字符串
xsdf.scope.values
# Out:
# array(['浙江省-杭州市-萧山区-义桥镇-罗幕行政村-王家桥自然村、浙江省杭州市萧山区义桥镇王家桥农贸市场等一带',
#        '浙江省-杭州市-萧山区-河庄街道-闸北行政村-闸北自然村、河庄街道闸北村、闸北行政村一带',
#        '浙江省-杭州市-萧山区-南阳街道-南兴行政村(南北自然村,南兴自然村,南联自然村),南阳街道(岩峰行政村-岩峰自然村,横蓬行政村-横蓬自然村);南阳街道(横蓬行政村-杭州萧山亚美精细化工有限公司,南兴行政村-中铁武汉电气化局集团输变电工程有限公司)、南阳街道岩峰行政村岩峰自然村234号、浙江省杭州市萧山区南阳街道岩峰村11号变一带',
#        ..., '浙江省-杭州市-萧山区-北干街道-信息港社区-建设四路',
#        '浙江省-杭州市-萧山区-瓜沥镇-长联行政村(长沙路,长沙自然村),瓜沥镇-解放行政村(解放自然村,长沙路);瓜沥镇(杭州萧山腾飞布业有限公司,中国电信股份有限公司杭州萧山区分公司,杭州新丝路布业有限公司,杭州富士迪装饰材料有限公司)',
#        '浙江省-杭州市-萧山区-新塘街道-傅楼行政村(傅家畈自然村,河南娄自然村,河北楼自然村)，新塘街道福楼村河北楼1号等'],
#       dtype=object)

# %%
# 拿到不以省市区开头的字符串的索引
np.where(~ np.array([_.startswith('浙江省-杭州市-萧山区') for _ in xsdf.scope.values]))

# 看看什么情况（或者直接先扔掉？？ hhh）

# 时间紧 先扔掉吧，也不多反正
# Out:
# (array([ 358,  412,  464,  479,  485,  611,  612,  613,  664,  666,  667,
#          678,  771,  782,  784,  791,  793,  802,  809,  898,  911,  917,
#          930,  935,  957,  958,  960, 1012, 1032, 1039, 1052, 1068, 1077,
#         1082, 1084, 1086, 1093, 1094, 1095, 1139, 1141, 1155, 1203, 1210,
#         1213, 1225, 1227, 1282, 1307, 1311, 1334, 1336, 1339], dtype=int64),)

# %%
# 扔掉了
for each in np.where(~ np.array([_.startswith('浙江省-杭州市-萧山区') for _ in xsdf.scope.values]))[0]:
    xsdf = xsdf.drop( each)

# %%
t = xsdf['scope'].values
t = list(t)
t[:10]
# Out:
# ['浙江省-杭州市-萧山区-义桥镇-罗幕行政村-王家桥自然村、浙江省杭州市萧山区义桥镇王家桥农贸市场等一带',
#  '浙江省-杭州市-萧山区-河庄街道-闸北行政村-闸北自然村、河庄街道闸北村、闸北行政村一带',
#  '浙江省-杭州市-萧山区-南阳街道-南兴行政村(南北自然村,南兴自然村,南联自然村),南阳街道(岩峰行政村-岩峰自然村,横蓬行政村-横蓬自然村);南阳街道(横蓬行政村-杭州萧山亚美精细化工有限公司,南兴行政村-中铁武汉电气化局集团输变电工程有限公司)、南阳街道岩峰行政村岩峰自然村234号、浙江省杭州市萧山区南阳街道岩峰村11号变一带',
#  '浙江省-杭州市-萧山区-宁围镇-宁围街道-丰东行政村-文明路、顺丰家园小区、顺丰家园24幢等一带',
#  '浙江省-杭州市-萧山区-靖江街道-花神庙社区-花神庙自然村;靖江街道-花神庙社区(杭州市公安局萧山区分局,杭州煜辉活塞销厂)一带',
#  '浙江省-杭州市-萧山区-义桥镇-丁家庄行政村(丁家庄自然村,戴家里自然村);浙江省-杭州市-萧山区-义桥镇-徐童山下行政村-杭州浦阳江水泥有限公司,义桥镇-丁家庄行政村(杭州浦阳江水泥有限公司,杭州萧山交投资产经营开发有限公司)一带',
#  '浙江省-杭州市-萧山区-南阳街道-横蓬行政村-横蓬自然村,南阳街道-南兴行政村(南北自然村,南兴自然村,南联自然村),南阳街道-岩峰行政村(岩峰自然村,港城大道,十米路);南阳街道-南兴行政村(华锦建设集团股份有限公司,中铁武汉电气化局集团工程有限公司),南阳街道-岩峰行政村(杭州益森实业有限公司,杭州青龙内衣厂,杭州沈士铝业有限公司,杭州锦鸿包装有限公司,杭州大宁油嘴油泵有限公司,杭州恒秀花边有限公司,杭州市萧山区人民政府南阳街道办事处),南阳街道(横蓬行政村-杭州萧山亚美精细化工有限公司,东风行政村-浙江德晨置业有限公司,龙虎行政村-杭州成邦沥青混凝土有限公司)、南阳街道岩峰行政村、南阳街道岩峰村461号一带',
#  '浙江省-杭州市-萧山区-宁围镇、宁围街道(盈一行政村-盈一自然村,二桥行政村-新北自然村)等一带',
#  '浙江省-杭州市-萧山区-蜀山街道-沈家里社区-沈家里路盛和苑、盛和苑118号、蜀山街道盛和苑一带',
#  '浙江省-杭州市-萧山区-戴村镇-戴村行政村-戴村自然村,戴村镇-八都行政村(中潭自然村,大山坪自然村,盛家自然村,麦园自然村,前方自然村,马谷新村自然村),戴村镇-三头行政村(墙头自然村,大湖头自然村,凌桥自然村),戴村镇-半山行政村(丁村自然村,凌山自然村),戴村镇-马谷行政村(马谷自然村,马谷新村自然村);戴村镇(杭州市萧山区林场,杭州拂晓新材料科技有限公司,杭州萧山电子kaiguan实业有限公司,萧山第六高级中学,杭州互信机械有限公司,杭州恺友塑胶有限公司,杭州锋濠铝业有限公司,杭州海菱电器设备有限公司,杭州合力包装材料有限公司)，浙江省杭州市萧山区戴村镇三头行政村墙头自然村92号，浙江省杭州市萧山区戴村镇三头村凌桥171号，浙江省杭州市萧山区戴村镇三头行政村凌桥自然村3组78号等']

# %%
# 去掉前缀
t = [_[12:] for _ in t]
t[:10]
# Out:
# ['义桥镇-罗幕行政村-王家桥自然村、浙江省杭州市萧山区义桥镇王家桥农贸市场等一带',
#  '河庄街道-闸北行政村-闸北自然村、河庄街道闸北村、闸北行政村一带',
#  '南阳街道-南兴行政村(南北自然村,南兴自然村,南联自然村),南阳街道(岩峰行政村-岩峰自然村,横蓬行政村-横蓬自然村);南阳街道(横蓬行政村-杭州萧山亚美精细化工有限公司,南兴行政村-中铁武汉电气化局集团输变电工程有限公司)、南阳街道岩峰行政村岩峰自然村234号、浙江省杭州市萧山区南阳街道岩峰村11号变一带',
#  '宁围镇-宁围街道-丰东行政村-文明路、顺丰家园小区、顺丰家园24幢等一带',
#  '靖江街道-花神庙社区-花神庙自然村;靖江街道-花神庙社区(杭州市公安局萧山区分局,杭州煜辉活塞销厂)一带',
#  '义桥镇-丁家庄行政村(丁家庄自然村,戴家里自然村);浙江省-杭州市-萧山区-义桥镇-徐童山下行政村-杭州浦阳江水泥有限公司,义桥镇-丁家庄行政村(杭州浦阳江水泥有限公司,杭州萧山交投资产经营开发有限公司)一带',
#  '南阳街道-横蓬行政村-横蓬自然村,南阳街道-南兴行政村(南北自然村,南兴自然村,南联自然村),南阳街道-岩峰行政村(岩峰自然村,港城大道,十米路);南阳街道-南兴行政村(华锦建设集团股份有限公司,中铁武汉电气化局集团工程有限公司),南阳街道-岩峰行政村(杭州益森实业有限公司,杭州青龙内衣厂,杭州沈士铝业有限公司,杭州锦鸿包装有限公司,杭州大宁油嘴油泵有限公司,杭州恒秀花边有限公司,杭州市萧山区人民政府南阳街道办事处),南阳街道(横蓬行政村-杭州萧山亚美精细化工有限公司,东风行政村-浙江德晨置业有限公司,龙虎行政村-杭州成邦沥青混凝土有限公司)、南阳街道岩峰行政村、南阳街道岩峰村461号一带',
#  '宁围镇、宁围街道(盈一行政村-盈一自然村,二桥行政村-新北自然村)等一带',
#  '蜀山街道-沈家里社区-沈家里路盛和苑、盛和苑118号、蜀山街道盛和苑一带',
#  '戴村镇-戴村行政村-戴村自然村,戴村镇-八都行政村(中潭自然村,大山坪自然村,盛家自然村,麦园自然村,前方自然村,马谷新村自然村),戴村镇-三头行政村(墙头自然村,大湖头自然村,凌桥自然村),戴村镇-半山行政村(丁村自然村,凌山自然村),戴村镇-马谷行政村(马谷自然村,马谷新村自然村);戴村镇(杭州市萧山区林场,杭州拂晓新材料科技有限公司,杭州萧山电子kaiguan实业有限公司,萧山第六高级中学,杭州互信机械有限公司,杭州恺友塑胶有限公司,杭州锋濠铝业有限公司,杭州海菱电器设备有限公司,杭州合力包装材料有限公司)，浙江省杭州市萧山区戴村镇三头行政村墙头自然村92号，浙江省杭州市萧山区戴村镇三头村凌桥171号，浙江省杭州市萧山区戴村镇三头行政村凌桥自然村3组78号等']

# %%
# 字符串十分不规则，比较棘手的是括号中的内容。
# 今天我们先省事儿，直接把括号中的内容扔掉， 只用外面的信息，然后以顿号逗号为分隔符断开

import re

# %%
# 写两个正则即可，然后试一试先
p_droph = re.compile( '\(.+?\)')
p_dropAnySpl = re.compile( r'，|,|、|;|；') 
p_dropg = re.compile(r'一带|等')
s = '南阳街道-南兴行政村(南北自然村,南兴自然村,南联自然村),南阳街道(岩峰行政村-岩峰自然村,横蓬行政村-横蓬自然村);南阳街道(横蓬行政村-杭州萧山亚美精细化工有限公司,南兴行政村-中铁武汉电气化局集团输变电工程有限公司)、南阳街道岩峰行政村岩峰自然村234号、浙江省杭州市萧山区南阳街道岩峰村11号变一带'
s = p_droph.sub('', s)
s
# Out:
# '南阳街道-南兴行政村,南阳街道;南阳街道、南阳街道岩峰行政村岩峰自然村234号、浙江省杭州市萧山区南阳街道岩峰村11号变一带'

# %%
s = p_dropAnySpl.sub(';', s)
s
# Out:
# '南阳街道-南兴行政村;南阳街道;南阳街道;南阳街道岩峰行政村岩峰自然村234号;浙江省杭州市萧山区南阳街道岩峰村11号变一带'

# %%
s = p_dropg.sub('', s)
s
# Out:
# '南阳街道-南兴行政村;南阳街道;南阳街道;南阳街道岩峰行政村岩峰自然村234号;浙江省杭州市萧山区南阳街道岩峰村11号变'

# %%
# ok 做一个地点全集，批量传给api；各组也要去重
addrs = set()

for i in range(len(t)):
    t[i] = p_droph.sub('', t[i])
    t[i] = p_dropAnySpl.sub(';', t[i])
    t[i] = p_dropg.sub('', t[i])
    
    
    t[i] = t[i].split(';')
    if '' in t[i]: t[i].remove('')

    t[i] = set(t[i])
    addrs = addrs.union(t[i])

# %%
f = open('addrs.txt', 'w+', encoding='utf8')
for each in addrs:
    if '杭州' not in each:
        each = '杭州'+each
    f.write(each+"\n")

# %%
len(t)
# Out:
# 2787

# %%
len(addrs)
# Out:
# 5339

# %%
addrs.remove('')

# 由于set是无序容器，而百度的这个api是没有转化前文本的；所以我们在转完后再转回来。
addrs = list(addrs)

# %%
import requests

url = 'http://api.map.baidu.com/geocoding/v3/?address={}&output=json&ak=7sqVWLuyZYXlxWcA4YwvZa3hFXKbfec2&callback=showLocation'
rspss = []
i = 0
for each in  addrs:
    if '杭州' not in each:
        each = '杭州市'+each
    i += 1
    print('GET:', each, i, 'of 5000')
    rsps = requests.get(url.format(each))
    rspss.append(rsps)
# Out:
# 746 of 5000
# GET: 杭州市宁围街道-萧山开发区国有资产经营有限公司 4747 of 5000
# GET: 杭州市群欢自然村 4748 of 5000
# GET: 杭州市瓜沥镇瓜沥镇殿下路119号 4749 of 5000
# GET: 杭州市萧山区新街街道长山头行政村中国石油加油站 4750 of 5000
# GET: 杭州市河庄街道建设行政村9组32号 4751 of 5000
# GET: 杭州市临浦镇-峙山西路 4752 of 5000
# GET: 杭州市盈中村 4753 of 5000
# GET: 杭州市南阳街道-横蓬行政村横蓬村 4754 of 5000
# GET: 靖江街道-靖港行政村(杭州永恒纺织机械有限公司 4755 of 5000
# GET: 杭州市新街街道-新街镇-陈家园行政村-陈家园自然村 4756 of 5000
# GET: 杭州市南庄路 4757 of 5000
# GET: 杭州市城厢街道-育才东苑社区 4758 of 5000
# GET: 浙江省杭州市萧山区戴村镇三头村凌桥171号 4759 of 5000
# GET: (杭州涵基汽车配件有限公司 4760 of 5000
# GET: 杭州政源轴承机械厂 4761 of 5000
# GET: 杭州浩天物业管理有限公司 4762 of 5000
# GET: 杭州市党湾镇-新梅行政村 4763 of 5000
# GET: 杭州市党湾镇永安行政村2组 4764 of 5000
# GET: 杭州市宁围街道-钱江社区有限公司 4765 of 5000
# GET: 杭州萧山景福印染有限公司 4766 of 5000
# GET: 杭州联强物资回收有限公司萧山分公司 4767 of 5000
# GET: 浙江省杭州市萧山区鸿宁路401号 4768 of 5000
# GET: 杭州市宁围街道-宁安社区 4769 of 5000
# GET: 杭州市南闸口弄 4770 of 5000
# GET: 杭州市浦阳镇-桃北新行政村 4771 of 5000
# GET: 杭州市南虹路 4772 of 5000
# GET: 浙江省杭州市萧山区宁围街道合丰行政村利丰路柏峰珑悦府1幢3单元802室 4773 of 5000
# GET: 杭州萧山瓜沥二联校办化纤织造厂 4774 of 5000
# GET: 杭州市瓜沥镇世安桥行政村世安桥自然村14号 4775 of 5000
# GET: 杭州市北干街道-荣星社区 4776 of 5000
# GET: 杭州市所前镇-联谊行政村-杨树下自然村 4777 of 5000
# GET: 杭州市新湾街道蓝商路 4778 of 5000
# GET: 杭州市宁围镇钱江新村一区31-2-502 4779 of 5000
# GET: 杭州市衙前镇-杨汛行政村 4780 of 5000
# GET: 浙江省杭州市萧山区进化镇束上王村 4781 of 5000
# GET: 杭州市东湖头自然村 4782 of 5000
# GET: 杭州市蜀山街道-越寨社区 4783 of 5000
# GET: 杭州市闻堰街道 4784 of 5000
# GET: 杭州凯赛嘉机械有限公司 4785 of 5000
# GET: 杭州新世纪机电设备有限公司 4786 of 5000
# GET: 杭州市萧山区新湾镇萧东村（围垦用电） 4787 of 5000
# GET: 瓜沥镇勇建行政村-杭州恒绿机械有限公司 4788 of 5000
# GET: 杭州市瓜沥镇-东恩行政村-东恩自然村 4789 of 5000
# GET: 杭州市河上镇-璇山下行政村-璇山下自然村 4790 of 5000
# GET: 杭州市瓜沥镇车路湾行政村车路湾自然村12号 4791 of 5000
# GET: 赭山社区-杭州萧山宝苑医院有限公司 4792 of 5000
# GET: 杭州萧山三盈实业公司 4793 of 5000
# GET: 杭州大江东产业集聚区水利工程管理所) 4794 of 5000
# GET: 杭州市杏花村 4795 of 5000
# GET: 进化镇-凤凰山行政村-杭州萧山污水处理有限公司 4796 of 5000
# GET: 杭州市新塘街道-浙东行政村 4797 of 5000
# GET: 杭州市瓜沥镇-渔庄行政村 4798 of 5000
# GET: 杭州市共建行政村 4799 of 5000
# GET: 浙江省杭州市萧山区义桥镇罗幕行政村新农村 4800 of 5000
# GET: 杭州市宁围街道创业路88号军民闸 4801 of 5000
# GET: 杭州市靖江街道 4802 of 5000
# GET: 浙江省杭州市萧山区新塘街道五联行政村陈端路827号 4803 of 5000
# GET: 杭州市嘉利公寓 4804 of 5000
# GET: 杭州市西兴顺坝围垦 4805 of 5000
# GET: 杭州市闻堰镇-湘湖社区-湘湖路 4806 of 5000
# GET: 浙江省杭州市萧山区临浦镇白露塘村 4807 of 5000
# GET: 杭州市萧山区靖江镇靖港村民委员会（围垦用电） 4808 of 5000
# GET: 楼塔镇-大同三行政村-杭州互投网络科技有限公司 4809 of 5000
# GET: 杭州市临浦镇-横一行政村-横山傅自然村 4810 of 5000
# GET: 杭州市萧山区瓜沥镇沙田头村（围垦用电） 4811 of 5000
# GET: 杭州市闸口路与兴隆路交叉口 4812 of 5000
# GET: 浙江省-杭州市-萧山区-南阳街道-赭山社区-中国民用航空华东地区空中交通管理局浙江分局 4813 of 5000
# GET: 义蓬街道-六工段片区-杭州帝凯化工有限公司 4814 of 5000
# GET: 杭州市围镇 4815 of 5000
# GET: 杭州市党湾镇幸福行政村 4816 of 5000
# GET: 浙江省-杭州市-萧山区-北干街道-金风社区-广东中奥物业管理有限公司萧山分公司 4817 of 5000
# GET: 浙江省杭州市萧山区河上镇联发村 4818 of 5000
# GET: 杭州市221号 4819 of 5000
# GET: 杭州市共建村10组28号 4820 of 5000
# GET: 杭州市萧山区前进街道三丰村村民委员会 4821 of 5000
# GET: 浙江省杭州市萧山区新街街道同心村（红星C920线） 4822 of 5000
# GET: 杭州市河庄街道蜀南小区 4823 of 5000
# GET: 杭州市甘露亭村 4824 of 5000
# GET: 杭州市河庄路 4825 of 5000
# GET: 杭州市围垦垦区-十八工段片区) 4826 of 5000
# GET: 红山农场-同心社区(杭州萧山红胜纺织有限公司 4827 of 5000
# GET: 杭州威玛轴承制造有限公司 4828 of 5000
# GET: 杭州市萧山区人民政府前进街道办事处) 4829 of 5000
# GET: 杭州市振兴路 4830 of 5000
# GET: 前进街道.前进街道江东大道4668号杭州前进科技有限公司 4831 of 5000
# GET: 杭州市瓜沥镇中沙村 4832 of 5000
# GET: 杭州市头蓬社区-集镇 4833 of 5000
# GET: 杭州市振宁社区-生兴路 4834 of 5000
# GET: 杭州市群谊自然村 4835 of 5000
# GET: 浙江省-杭州市-萧山区-新街街道-山末址行政村-绍兴市柯桥区杭绍城际轨道交通建设投资有限公司 4836 of 5000
# GET: 杭州市芝兰村 4837 of 5000
# GET: 杭州市萧西路 4838 of 5000
# GET: 杭州市前进街道-临江行政村-长征自然村 4839 of 5000
# GET: 杭州市城河街21号华职商城 4840 of 5000
# GET: 杭州前高贸易有限公司 4841 of 5000
# GET: 杭州市靖港村 4842 of 5000
# GET: 浙江省杭州市萧山区新街镇长山工人路 4843 of 5000
# GET: 杭州市萧山区党山镇群益村 4844 of 5000
# GET: 杭州市市政园林管理处 4845 of 5000
# GET: 杭州市衙前镇-明华行政村-明华自然村 4846 of 5000
# GET: 杭州市南阳街道-南翔行政村 4847 of 5000
# GET: 杭州市浙江宏基租赁有限公司 4848 of 5000
# GET: 杭州市宁牧村老年过渡房 4849 of 5000
# GET: 杭州市育才西苑28幢 4850 of 5000
# GET: 浙江省-杭州市-萧山区-河庄街道-建一行政村-中国水利水电第十四工程局有限公司杭州大江东基础设施项目经理部 4851 of 5000
# GET: 浙江省杭州市萧山区索前镇山联村 4852 of 5000
# GET: 杭州市义桥镇-七里店行政村 4853 of 5000
# GET: 杭州市双圩村4组 4854 of 5000
# GET: 杭州市光明四垦种) 4855 of 5000
# GET: 杭州市北干街道-明星行政村 4856 of 5000
# GET: 杭州市新街镇-新街街道-红山农场-同心社区-六分场 4857 of 5000
# GET: 杭州市新街街道-盛东行政村 4858 of 5000
# GET: 杭州市新街镇-新街街道-元沙行政村-元沙自然村 4859 of 5000
# GET: 杭州市钱江链条传动公司 4860 of 5000
# GET: 杭州市进化镇-裘家坞行政村-裘家坞自然村 4861 of 5000
# GET: 杭州市瓜沥镇-塘头社区(殿下路 4862 of 5000
# GET: 杭州市梅仙自然村 4863 of 5000
# GET: 杭州市戴村镇-戴村行政村-戴村自然村 4864 of 5000
# GET: 靖江街道-靖东行政村-杭州天丽花边有限公司 4865 of 5000
# GET: 浙江开元酒店管理股份有限公司杭州开元名都大酒店 4866 of 5000
# GET: 杭州市义桥镇-蛟山行政村 4867 of 5000
# GET: 杭州市红垦小区 4868 of 5000
# GET: 杭州市城厢街道-杜湖社区-湘西路 4869 of 5000
# GET: 杭州市宁围街道宁围街道二桥行政村 4870 of 5000
# GET: 杭州市共裕村 4871 of 5000
# GET: 杭州市瓜沥镇城中社区7组 4872 of 5000
# GET: 浙江省杭州市萧山区戴春镇尖山下村 4873 of 5000
# GET: 杭州市萧山区碧桂园珑悦1幢2单元202室 4874 of 5000
# GET: 杭州市临浦镇-三峰行政村 4875 of 5000
# GET: 浙江省杭州市萧山区戴村镇石马头新村新区 4876 of 5000
# GET: 杭州萧山新塘欢明羽粉厂) 4877 of 5000
# GET: 杭州新晟禾实业有限公司 4878 of 5000
# GET: 浙江省杭州市萧山区经济技术开发区建设4路1078号 4879 of 5000
# GET: 浙江省杭州市萧山区山联村 4880 of 5000
# GET: 浙江省杭州市萧山区义桥镇丁家庄村李丁自然村 4881 of 5000
# GET: 浙江省杭州市萧山区浦阳镇桃北新行政村桃北新村36幢2单元301室 4882 of 5000
# GET: 杭州农港农副产品有限公司 4883 of 5000
# GET: 杭州萧山围垦十七工段周丽饲料加工厂 4884 of 5000
# GET: 杭州市新塘街道-姑娘桥行政村 4885 of 5000
# GET: 杭州市新城香悦公馆 4886 of 5000
# GET: 杭州市新塘街道-商城社区-长青路 4887 of 5000
# GET: 杭州市义盛村 4888 of 5000
# GET: 杭州市靖江街道商贸街301号 4889 of 5000
# GET: 杭州市宁围镇-宁围街道-宁税社区 4890 of 5000
# GET: 杭州市苏黎士小镇排屋 4891 of 5000
# GET: 杭州市北干街道-风情大道-腾达建设集团股份有限公司 4892 of 5000
# GET: 杭州市瓜沥镇-芭蕉砚社区-殿下路 4893 of 5000
# GET: 杭州市河上镇-溪头行政村 4894 of 5000
# GET: 杭州市莱茵传奇园3幢 4895 of 5000
# GET: 杭州市有限公司 4896 of 5000
# GET: 临浦镇-塘郎孙行政村-杭州萧山利达纺织服饰有限公司 4897 of 5000
# GET: 杭州市河庄街道同一村七组二号 4898 of 5000
# GET: 杭州市潘水路 4899 of 5000
# GET: 浙江省-杭州市-萧山区-城厢街道-育才东苑社区-浙江金马酒店管理有限公司 4900 of 5000
# GET: 临浦镇-华家行政村-杭州井盛包装有限公司 4901 of 5000
# GET: 浙江省杭州市萧山区所前镇老所前中心路 4902 of 5000
# GET: 杭州市瓜沥镇-八大行政村 4903 of 5000
# GET: 杭州市城厢街道-西河路社区-西河路 4904 of 5000
# GET: 杭州市公安局) 4905 of 5000
# GET: 杭州萧山钱江话筒厂 4906 of 5000
# GET: 杭州市萧山区瓜沥镇志龙特种养殖场 4907 of 5000
# GET: 浙江省杭州市萧山区宁围镇合丰行政村利丰路柏峰珑悦府1幢1单元1501室 4908 of 5000
# GET: 浙江省杭州市萧山区临浦镇新河行政村6庄新区23号 4909 of 5000
# GET: 浙江省杭州市萧山区浦阳镇桃园村 4910 of 5000
# GET: 杭州市潮峰钢构集团有限公司 4911 of 5000
# GET: 杭州市歪桥自然村 4912 of 5000
# GET: 杭州市新港村 4913 of 5000
# GET: 杭州市万安行政村-四化路 4914 of 5000
# GET: 杭州市新塘街道-傅楼行政村-徐纪产 4915 of 5000
# GET: 杭州杭通汽车轴承有限公司 4916 of 5000
# GET: 杭州市北干街道-市北社区 4917 of 5000
# GET: 杭州华超紧固件有限公司 4918 of 5000
# GET: 杭州市闻堰镇-南岸社区-时代大道 4919 of 5000
# GET: 杭州双象汽车零部件有限公司 4920 of 5000
# GET: 杭州市北干街道-高田社区-萧绍路 4921 of 5000
# GET: 杭州萧山城市建设投资集团有限公司 4922 of 5000
# GET: 杭州市展业海绵制品公司 4923 of 5000
# GET: 杭州市靖江街道-和顺行政村-萧山裕丰氨纶化纤厂 4924 of 5000
# GET: 浙江省杭州市萧山区宁围街道新安行政村富滨名座 4925 of 5000
# GET: 杭州市和美家小区 4926 of 5000
# GET: 浙江省杭州市萧山区进化镇祝家村218号 4927 of 5000
# GET: 杭州市新华村中小区 4928 of 5000
# GET: 杭州市前进街道-八工段片区 4929 of 5000
# GET: 杭州市所前镇-祥里王行政村-祥里王自然村 4930 of 5000
# GET: 杭州市风情大道金色钱塘家园15幢1单元1402室 4931 of 5000
# GET: 杭州市瓜沥镇-世安桥行政村 4932 of 5000
# GET: 杭州市新湾街道冯溇行政村 4933 of 5000
# GET: 杭州市新街街道-红垦社区 4934 of 5000
# GET: 杭州市围垦垦区-八工段片区 4935 of 5000
# GET: 杭州丹诗丽装饰有限公司 4936 of 5000
# GET: 杭州市恒园小区 4937 of 5000
# GET: 杭州市城厢街道-百尺溇社区-百尺溇路 4938 of 5000
# GET: 杭州市所前镇-杜家行政村 4939 of 5000
# GET: 杭州市城厢街道-美之园社区-跨月路 4940 of 5000
# GET: 浙江省杭州市萧山区楼塔镇大黄林村 4941 of 5000
# GET: 杭州市义桥镇-湘东行政村 4942 of 5000
# GET: 杭州市北干街道-湖滨花园社区-博奥路 4943 of 5000
# GET: 杭州市衙前镇-项漾行政村-优胜自然村 4944 of 5000
# GET: 杭州蓝田涂料有限公司 4945 of 5000
# GET: 浙江省-杭州市-萧山区-新街街道-新塘头行政村-浙江旅游职业学院 4946 of 5000
# GET: 杭州市义蓬街道头蓬社区诚意公寓2幢1单元202室 4947 of 5000
# GET: 浙江省杭州市萧山区宁围镇 4948 of 5000
# GET: 杭州市萧山区新湾街道共和村经济联合社 4949 of 5000
# GET: 杭州市瓜历镇坎山甘露亭村3组和4组 4950 of 5000
# GET: 杭州市浦阳镇-径游行政村-汪家塘自然村 4951 of 5000
# GET: 浙江省-杭州市-萧山区-义桥镇-新坝行政村-杭州建国机电有限公司 4952 of 5000
# GET: 浙江省杭州市萧山区江南自然村18组16号 4953 of 5000
# GET: 浙江省杭州市萧山区戴村镇东风村 4954 of 5000
# GET: 浙江省杭州市萧山区新塘街道裘江新村 4955 of 5000
# GET: 杭州市坎山镇三岔路村 4956 of 5000
# GET: 杭州市靖江街道-靖港行政村 4957 of 5000
# GET: 所前镇-杭州明辉玻璃有限公司 4958 of 5000
# GET: 杭州萧山经济技术开发区国有资产经营有限公司 4959 of 5000
# GET: 杭州市头蓬街道南沙村 4960 of 5000
# GET: 河上镇-众联行政村-杭州长虹路桥工程有限公司 4961 of 5000
# GET: 杭州市萧杭路 4962 of 5000
# GET: 杭州市城厢街道-南市社区-拱秀路 4963 of 5000
# GET: 杭州市大江东河庄 4964 of 5000
# GET: 杭州市浙江宁围环境服务有限公司 4965 of 5000
# GET: 浙江省杭州市萧山区所前镇越王村 4966 of 5000
# GET: 杭州市围垦垦区-十三工段片区) 4967 of 5000
# GET: 浙江省杭州市萧山区临浦镇横一行政村梅里自然村11组18号 4968 of 5000
# GET: 杭州市进化镇-平阳行政村 4969 of 5000
# GET: 杭州绿宇生物工程有限公司 4970 of 5000
# GET: 瓜沥镇-新港行政村-杭州厚生纸业有限公司 4971 of 5000
# GET: 杭州市顺发恒园 4972 of 5000
# GET: 杭州市创新村 4973 of 5000
# GET: 杭州户助投资有限公司 4974 of 5000
# GET: 杭州市宇祥房产 4975 of 5000
# GET: 杭州市陈家园村 4976 of 5000
# GET: 杭州金匀盛科技有限公司 4977 of 5000
# GET: 杭州耀东钢结构有限公司 4978 of 5000
# GET: 杭州市宁围镇金二路与建设二路交叉口 4979 of 5000
# GET: 杭州市瓜沥镇-碧苑新村社区-七区自然村 4980 of 5000
# GET: 杭州艾力森实业有限公司 4981 of 5000
# GET: 北干街道-杭州中兴物业管理中心 4982 of 5000
# GET: 杭州市城厢街道-百尺溇社区 4983 of 5000
# GET: 杭州市东方自然村 4984 of 5000
# GET: 杭州市靖江街道-东桥行政村-东桥自然村 4985 of 5000
# GET: 杭州市城厢街道-潘水社区 4986 of 5000
# GET: 浙江省杭州市萧山区进化镇富登村7号压器 4987 of 5000
# GET: 浙江省杭州市萧山区新塘街道朱家坛行政村264号 4988 of 5000
# GET: 杭州市杜湖村老年安置房 4989 of 5000
# GET: 杭州市永联行政村镇海22组40号 4990 of 5000
# GET: 杭州市河庄 4991 of 5000
# GET: 杭州市潮洪建材公司 4992 of 5000
# GET: 杭州市瓜沥镇工农村853号附近 4993 of 5000
# GET: 杭州市靖江街道-甘露行政村 4994 of 5000
# GET: 杭州市南阳镇南丰村 4995 of 5000
# GET: 杭州市瓜沥镇-中沙行政村 4996 of 5000
# GET: 杭州市居委会 4997 of 5000
# GET: 杭州市戴村镇-骆家舍行政村 4998 of 5000
# GET: 进化镇浙江省杭州市萧山区金化镇凤凰山村 4999 of 5000
# GET: 浙江省杭州市萧山区楼塔镇大同二行政村 5000 of 5000
# GET: 杭州市7号 5001 of 5000
# GET: 浙江省-杭州市-萧山区-瓜沥镇-前兴行政村-杭州萧山瓜沥镇前兴村经济联合社 5002 of 5000
# GET: 杭州市新湾临江村新峰十组11号 5003 of 5000
# GET: 杭州市前进街道-前进街道社区) 5004 of 5000
# GET: 杭州市新塘街道-畈里童社区 5005 of 5000
# GET: 杭州市光明四垦种 5006 of 5000
# GET: 杭州市新湾街道- 5007 of 5000
# GET: 靖江街道-黎明社区-杭州工驹格纺机科技有限公司 5008 of 5000
# GET: 杭州萧山城市建筑有限公司 5009 of 5000
# GET: 杭州市181号 5010 of 5000
# GET: 杭州市115-117号 5011 of 5000
# GET: 杭州市萧山区新街街道江南村19组 5012 of 5000
# GET: 杭州市后花园 5013 of 5000
# GET: 浙江省杭州市萧山区新塘街道汇宇社区南秀路晶典公寓 5014 of 5000
# GET: 杭州市瓜沥镇坎山镇张神殿村 5015 of 5000
# GET: 杭州市所前镇金临湖行政村里士湖 5016 of 5000
# GET: 杭州市萧山区滨康路55号龙乐公寓 5017 of 5000
# GET: 杭州市大江东开发区 5018 of 5000
# GET: 围垦垦区-外七工段片区-杭州荣丰农业开发有限公司 5019 of 5000
# GET: 杭州市西湘弄 5020 of 5000
# GET: 杭州市五联村难言达151号 5021 of 5000
# GET: 杭州市萧山区丹婷艺术培训学校 5022 of 5000
# GET: 杭州市萧山市新街镇长山食品厂 5023 of 5000
# GET: 浙江省杭州市萧山区临浦镇东麓池社区峙山西路73号 5024 of 5000
# GET: 杭州市经济技术开发区-江东工业园区-开氏石化股份有限公司 5025 of 5000
# GET: 杭州萧山新宇塑料薄膜包装厂 5026 of 5000
# GET: 杭州市新街镇-新街街道-新润社区-海塘路-钱啤小区 5027 of 5000
# GET: 杭州市育才路 5028 of 5000
# GET: 杭州市杏花自然村 5029 of 5000
# GET: 浙江省杭州市萧山区新塘街道畈里童社区畈里童自然村坂里童村新罗路128号 5030 of 5000
# GET: 浙江省杭州市萧山区义桥镇新意名苑10幢302 5031 of 5000
# GET: 杭州市沿塘自然村 5032 of 5000
# GET: 杭州市南阳街道-坞里行政村-浙江舒奇蒙能源科技有限公司 5033 of 5000
# GET: 杭州市萧山区党山镇长联村 5034 of 5000
# GET: 新街街道(花城社区-杭州市公安局 5035 of 5000
# GET: 杭州市南阳街道岩峰村 5036 of 5000
# GET: 杭州市新和村 5037 of 5000
# GET: 杭州市三围村 5038 of 5000
# GET: 杭州市垦辉二路 5039 of 5000
# GET: 义南行政村-杭州杰达仪表五金有限公司 5040 of 5000
# GET: 杭州市萧山区城市河道管理处 5041 of 5000
# GET: 浙江省-杭州市-萧山区-河庄街道-三联行政村-歌山建设集团有限公司 5042 of 5000
# GET: 杭州萧山金昌汽配厂) 5043 of 5000
# GET: 浙江省杭州市萧山区临浦镇浦二行政村蒲山韩自然村国火 5044 of 5000
# GET: 杭州市党湾镇-德北行政村-德北自然村 5045 of 5000
# GET: 浙江省杭州市萧山区新街镇新盛村杭州币控 5046 of 5000
# GET: 杭州市龙房自然村 5047 of 5000
# GET: 杭州市畈里汪自然村 5048 of 5000
# GET: 义桥镇-田丰行政村-杭州众木机电有限公司 5049 of 5000
# GET: 杭州市靖江街道黎明社区 5050 of 5000
# GET: 杭州市桥南经济开发区288号 5051 of 5000
# GET: 杭州舒乐化工有限公司 5052 of 5000
# GET: 杭州市106号 5053 of 5000
# GET: 杭州市宁围街道-钱江世纪城社区-浙商银行股份有限公司 5054 of 5000
# GET: 浙江省杭州市萧山区新街镇江南村华丰县 5055 of 5000
# GET: 杭州市丰沃达医药物流有限公司 5056 of 5000
# GET: 杭州市宁围街道振宁路万科大家世纪之光21幢904 5057 of 5000
# GET: 杭州市文化路 5058 of 5000
# GET: 杭州市威尼斯水城 5059 of 5000
# GET: 杭州市农贸市场门口 5060 of 5000
# GET: 杭州市回澜北苑10幢3单元502室 5061 of 5000
# GET: 杭州市宁围街道江南丽景 5062 of 5000
# GET: 杭州新银机械厂 5063 of 5000
# GET: 杭州市益农镇东村行政村-东村自然村 5064 of 5000
# GET: 杭州市星民垦殖厂 5065 of 5000
# GET: 杭州市新塘街道-下潦社区-浙江国泰建设集团有限公司 5066 of 5000
# GET: 浙江省杭州市萧山区四季城绷劲大道与市新路共享汽车 5067 of 5000
# GET: 杭州市围垦垦区-七工段片区 5068 of 5000
# GET: 杭州市新街镇-新街街道-盛中村-盛中行政村-盛中自然村 5069 of 5000
# GET: 浙江省杭州市萧山区戴村镇 5070 of 5000
# GET: 杭州市瓜沥镇芭蕉砚社区-殿下路 5071 of 5000
# GET: 杭州市河庄街道民主行政村-民主自然村 5072 of 5000
# GET: 杭州市新街街道-盛东行政村-盛东自然村 5073 of 5000
# GET: 杭州市临浦镇华家村162号 5074 of 5000
# GET: 杭州市党山镇山北村 5075 of 5000
# GET: 浙江省杭州市萧山区红山农场芝那 5076 of 5000
# GET: 杭州市升岭路150号 5077 of 5000
# GET: 杭州市靖江街道小石桥社区 5078 of 5000
# GET: 杭州市顺发堤香 5079 of 5000
# GET: 杭州市陈家园行政村-陈家园自然村 5080 of 5000
# GET: 杭州市谢家弄 5081 of 5000
# GET: 杭州市市心南路沿街 5082 of 5000
# GET: 杭州市党湾镇 5083 of 5000
# GET: 杭州市河上镇-紫霞行政村 5084 of 5000
# GET: 杭州萧山卓达建筑设备租赁部 5085 of 5000
# GET: 杭州市建一村一组 5086 of 5000
# GET: 杭州市河庄街道-同二行政村 5087 of 5000
# GET: 杭州市临江街道 5088 of 5000
# GET: 杭州盈中纺织有限公司 5089 of 5000
# GET: 杭州市美和桥北面 5090 of 5000
# GET: 杭州金溢钢网架制造有限公司 5091 of 5000
# GET: 杭州市瓜沥镇-沙田头行政村-沙田头自然村 5092 of 5000
# GET: 杭州市闻堰镇樟树村 5093 of 5000
# GET: 城厢街道-杭州萧山供水有限公司 5094 of 5000
# GET: 浙江省杭州市萧山区宁围镇合丰行政村利丰路柏峰珑悦府1幢1单元602室 5095 of 5000
# GET: 杭州市瓜沥镇建盈行政村-建盈自然村 5096 of 5000
# GET: 杭州市殿下路 5097 of 5000
# GET: 杭州市义蓬街道头蓬社区通围路 5098 of 5000
# GET: 杭州市南阳街道坞里行政村 5099 of 5000
# GET: 杭州市前进街道临江行政村临江小区1排11号 5100 of 5000
# GET: 杭州市闻堰镇-黄山行政村 5101 of 5000
# GET: 杭州市瓜沥镇-永联行政村-黄公娄自然村 5102 of 5000
# GET: 杭州市怡景公寓 5103 of 5000
# GET: 杭州旺禽羽毛粉有限公司 5104 of 5000
# GET: 浙江省-杭州市-萧山区-瓜沥镇-孙家弄行政村-杭州市萧山区瓜沥镇社区卫生服务中心 5105 of 5000
# GET: 杭州市西河路240号 5106 of 5000
# GET: 杭州市宝丰路 5107 of 5000
# GET: 浙江省杭州市萧山区楼塔镇楼塔开发区106号 5108 of 5000
# GET: 杭州市北干街道-北干一苑社区-山阴路凯悦花园 5109 of 5000
# GET: 杭州新时代彩印实业有限公司 5110 of 5000
# GET: 杭州市北干街道君悦丽景1幢1单元 5111 of 5000
# GET: 杭州市共裕行政村-共裕自然村 5112 of 5000
# GET: 杭州市新湾农办 5113 of 5000
# GET: 杭州市8幢及育才路（420 5114 of 5000
# GET: 浙江省杭州市萧山区义桥湘南村牌轩片4号 5115 of 5000
# GET: 杭州市文明路328号江宁大厦 5116 of 5000
# GET: 浙江省杭州市萧山区靖江街道黎明社区10组 5117 of 5000
# GET: 杭州阳城颜料化工有限公司 5118 of 5000
# GET: 杭州市蜀山街道-向阳社区 5119 of 5000
# GET: 浙江省-杭州市-萧山区-衙前镇-凤凰行政村-杭州萧山凤凰纺织有限公司 5120 of 5000
# GET: 杭州市153幢 5121 of 5000
# GET: 城厢街道-东湘社区-杭州萧山东湘加油站有限公司 5122 of 5000
# GET: 杭州市瓜沥镇三盈行政村盈二路 5123 of 5000
# GET: 杭州市瓜沥镇沿塘村 5124 of 5000
# GET: 杭州市龙湖天矩 5125 of 5000
# GET: 杭州市戴村镇-顾家溪行政村-勤工自然村 5126 of 5000
# GET: 杭州市宁牧村 5127 of 5000
# GET: 杭州市蜜蜂行政村-蜜蜂自然村 5128 of 5000
# GET: 杭州市益农镇-东村行政村-东村自然村 5129 of 5000
# GET: 杭州恒飞绣品有限公司 5130 of 5000
# GET: 经济技术开发区-钱江社区-杭州自祥铸造有限公司 5131 of 5000
# GET: 浙江省杭州市萧山区临浦镇临东社区 5132 of 5000
# GET: 杭州市党山镇单木桥村7组 5133 of 5000
# GET: 杭州市通惠南路 5134 of 5000
# GET: 浙江省杭州市萧山区楼塔镇楼英村 5135 of 5000
# GET: 杭州市瓜沥镇芭蕉砚社区人民路16号西街综合楼B座 5136 of 5000
# GET: 杭州市萧山分公司萧山区新街街道江南行政村10组 5137 of 5000
# GET: 杭州市南阳赭东村7组19号门口马路上 5138 of 5000
# GET: 杭州市煤炭研究所宿舍 5139 of 5000
# GET: 杭州市益农镇-久联行政村 5140 of 5000
# GET: 杭州市华瑞中心 5141 of 5000
# GET: 杭州市益农镇-民围行政村-民围自然村 5142 of 5000
# GET: 杭州萧山鸿发五金厂 5143 of 5000
# GET: 杭州市临浦集镇西江塘小区 5144 of 5000
# GET: 杭州市宁围镇-宁围街道-丰东行政村 5145 of 5000
# GET: 杭州萧山江城化工有限公司 5146 of 5000
# GET: 杭州市惠南街 5147 of 5000
# GET: 杭州市新街街道-芝兰行政村-芝兰自然村 5148 of 5000
# GET: 杭州恒燕机械有限公司 5149 of 5000
# GET: 浙江省杭州市萧山区河上镇众联村（前面有造山洞隧道的位置） 5150 of 5000
# GET: 浙江省杭州市萧山区新街街道长山头行政村北塘东路180号 5151 of 5000
# GET: 浙江省杭州市萧山区新街镇峰维村4组（音译） 5152 of 5000
# GET: 杭州市万丰自然村 5153 of 5000
# GET: 杭州市利群路 5154 of 5000
# GET: 浙江省杭州市萧山区进化镇诸坞行政村诸坞自然村 5155 of 5000
# GET: 杭州市江南丽锦小区 5156 of 5000
# GET: 杭州市靖江街道-雷东行政村-雷东自然村 5157 of 5000
# GET: 杭州海源水产养殖有限公司 5158 of 5000
# GET: 杭州市新塘街道-霞江行政村-霞江自然村 5159 of 5000
# GET: 杭州市临浦镇-前孔社区-前孔自然村 5160 of 5000
# GET: 杭州市萧山区红山农场六分厂 5161 of 5000
# GET: 杭州市72号 5162 of 5000
# GET: 杭州市河庄农贸市场 5163 of 5000
# GET: 浙江省-杭州市-萧山区-前进街道-前进工业园区-浙江联誉实业有限公司 5164 of 5000
# GET: 杭州市益农镇民围行政村 5165 of 5000
# GET: 杭州市远东自行车厂 5166 of 5000
# GET: 杭州萧山保险箱厂 5167 of 5000
# GET: 杭州市港城大道 5168 of 5000
# GET: 杭州市新街镇-新街街道-盈中行政村 5169 of 5000
# GET: 杭州市北干街道-萧然社区-工人路 5170 of 5000
# GET: 十工段片区-杭州晓阳水产品有限公司 5171 of 5000
# GET: 杭州市萧山区坎山镇荣新村（围垦电用） 5172 of 5000
# GET: 杭州市东街 5173 of 5000
# GET: 杭州市新塘街道-五联行政村 5174 of 5000
# GET: 杭州爱龙金属制品有限公司 5175 of 5000
# GET: 杭州市曙光村 5176 of 5000
# GET: 杭州市党湾镇-裕民行政村 5177 of 5000
# GET: 杭州市瓜沥镇-山北行政村 5178 of 5000
# GET: 杭州市靖江街道-靖南行政村-靖南自然村 5179 of 5000
# GET: 杭州市坎山镇群谊村垦种 5180 of 5000
# GET: 杭州市7组 5181 of 5000
# GET: 杭州市浦阳镇-尖山行政村 5182 of 5000
# GET: 杭州市大井弄 5183 of 5000
# GET: 杭州诚盈针织有限公司 5184 of 5000
# GET: 杭州华春减速机厂 5185 of 5000
# GET: 杭州市新街街道-长山头行政村-长山头自然村 5186 of 5000
# GET: 所前镇。浙江省杭州市萧山区所前镇金山行政村蔡东樊胡居杭州天然气有限公司 5187 of 5000
# GET: 杭州市蜀山街道-祝家桥社区-浙江交工集团股份有限公司 5188 of 5000
# GET: 杭州市萧山区党湾镇农业办公室 5189 of 5000
# GET: 杭州市临浦镇-临一行政村 5190 of 5000
# GET: 杭州市宁围街道-二桥行政村-新北自然村 5191 of 5000
# GET: 浙江省杭州市萧山区义桥镇联三村曹家里67 5192 of 5000
# GET: 杭州市党湾镇新梅行政村13组 5193 of 5000
# GET: 围垦垦区-外六工段片区-杭州建元隧道发展有限公司 5194 of 5000
# GET: 杭州市河上镇 5195 of 5000
# GET: 浙江省杭州市萧山区临浦镇三峰行政村 5196 of 5000
# GET: 杭州市新湾四垦种 5197 of 5000
# GET: 杭州市南阳街道雷山行政村雷山自然村1组16户 5198 of 5000
# GET: 杭州市蜀山街道-联华社区 5199 of 5000
# GET: 杭州市河庄新东化纤厂 5200 of 5000
# GET: 浙江省杭州市萧山区义桥镇金域三江 5201 of 5000
# GET: 杭州萧山党湾松森五金配件商行 5202 of 5000
# GET: 杭州翰维斯塑业有限公司 5203 of 5000
# GET: 杭州市厢街道回澜南苑社区拱秀路 5204 of 5000
# GET: 杭州市新街镇-新街街道-山末址行政村 5205 of 5000
# GET: 杭州市绣衣坊公厕 5206 of 5000
# GET: 新街街道(长山社区-杭州鸿达市政公用事业服务有限公司 5207 of 5000
# GET: 浙江省杭州市萧山区新街街道人民路157号 5208 of 5000
# GET: 杭州萧山河庄南钱菜厂 5209 of 5000
# GET: 杭州市楼塔镇-岩山行政村-岩下自然村 5210 of 5000
# GET: 杭州市萧山区瓜沥镇如松村村民委员会 5211 of 5000
# GET: 杭州市北干街道江南国际城 5212 of 5000
# GET: 杭州市所前镇孔湖村韩家山 5213 of 5000
# GET: 杭州市义蓬街道春园行政村 5214 of 5000
# GET: 杭州市义前街 5215 of 5000
# GET: 杭州市三联行政村 5216 of 5000
# GET: 杭州市瓜沥镇-靖一行政村-靖一自然村 5217 of 5000
# GET: 杭州市新龙村 5218 of 5000
# GET: 杭州市宁围和美家小区1幢6单元502室 5219 of 5000
# GET: 杭州市益农镇东沙行政村12组 5220 of 5000
# GET: 杭州市回澜南园110幢 5221 of 5000
# GET: 浙江省杭州市萧山区义桥镇罗峰社区丁家畈 5222 of 5000
# GET: 杭州市回澜北苑 5223 of 5000
# GET: 杭州市瓜沥镇-运东行政村 5224 of 5000
# GET: 杭州市萧山义盛红旗网络丝厂 5225 of 5000
# GET: 杭州市甘露自然村 5226 of 5000
# GET: 杭州萧山宁围金二股份经济联合社 5227 of 5000
# GET: 杭州市宁围街道-浙江万兴恒服务有限公司 5228 of 5000
# GET: 杭州市新北桥社区 5229 of 5000
# GET: 杭州市荣星东苑 5230 of 5000
# GET: 杭州市党湾镇-梅东行政村 5231 of 5000
# GET: 杭州市浙江汇德隆实业集团有限公司 5232 of 5000
# GET: 杭州市党湾镇-勤联行政村-勤联自然村 5233 of 5000
# GET: 杭州水祥水产养殖有限公司 5234 of 5000
# GET: 杭州市金腾混凝土厂 5235 of 5000
# GET: 杭州市浙江顺泰工程建设有限公司) 5236 of 5000
# GET: 杭州市红山农场五分场 5237 of 5000
# GET: 所前镇-杭州敏德科技有限公司 5238 of 5000
# GET: 杭州市市心北路98号都市阳光广场 5239 of 5000
# GET: 浙江省-杭州市-萧山区-进化镇-傅墩行政村-杭州萧山进化镇金诚拉丝厂 5240 of 5000
# GET: 浙江省杭州市萧山区进化镇欢汤村古默 5241 of 5000
# GET: 杭州市益农镇民围村 5242 of 5000
# GET: 杭州市浙江大行建设有限公司)瓜沥镇荣新村9组17户 5243 of 5000
# GET: 杭州良达宏包装科技有限公司) 5244 of 5000
# GET: 杭州万青毛衫有限公司 5245 of 5000
# GET: 杭州市火星村 5246 of 5000
# GET: 杭州市萧山区传关医院 5247 of 5000
# GET: 杭州曼雅琪服饰有限公司 5248 of 5000
# GET: 杭州市新街镇-新街街道-元沙村 5249 of 5000
# GET: 杭州市益农行政村 5250 of 5000
# GET: 杭州市新塘街道-商城社区-新惠名苑小区 5251 of 5000
# GET: 杭州晓阳水产品有限公司) 5252 of 5000
# GET: 浙江省杭州市萧山区义桥镇徐童山下村赵家头33号 5253 of 5000
# GET: 杭州市南阳街道赭山社区永里路13号 5254 of 5000
# GET: 杭州市萧山区城厢镇城北垦种 5255 of 5000
# GET: 杭州市77号 5256 of 5000
# GET: 浙江省杭州市萧山区新天街道杏中村(音译）5组11号 5257 of 5000
# GET: 杭州市戴村镇-青山行政村-狮山自然村 5258 of 5000
# GET: 杭州市湘湖家园79幢1单元 5259 of 5000
# GET: 杭州市萧山区河庄镇同二村村民委员会 5260 of 5000
# GET: 杭州市沈家直路 5261 of 5000
# GET: 杭州市靖江光明行政村 5262 of 5000
# GET: 杭州市瓜沥镇孙家弄行政村 5263 of 5000
# GET: 杭州市宁围镇-宁围街道-顺坝行政村-奔竞二路 5264 of 5000
# GET: 杭州市党湾五垦种 5265 of 5000
# GET: 杭州市河庄街道-蜀南行政村-蜀南自然村 5266 of 5000
# GET: 杭州市一自然村 5267 of 5000
# GET: 杭州市益农镇-赵家湾行政村-赵家湾自然村 5268 of 5000
# GET: 杭州市瓜沥镇单木桥村21组 5269 of 5000
# GET: 杭州市城中社区-红友桥路 5270 of 5000
# GET: 杭州市江东大道与恒英县交口工地 5271 of 5000
# GET: 杭州市宁安行政村 5272 of 5000
# GET: 杭州市蜀山街道-沈家里社区 5273 of 5000
# GET: 杭州市公安局大江东产业集聚区分局 5274 of 5000
# GET: 杭州市家乐公寓 5275 of 5000
# GET: 杭州市利一路与博奥路十字路口靠西边工地上 5276 of 5000
# GET: 杭州市靖江街道-黎明社区 5277 of 5000
# GET: 杭州市225号 5278 of 5000
# GET: 杭州市滨水名庭 5279 of 5000
# GET: 杭州市进化镇萧汉村3组17号 5280 of 5000
# GET: 杭州市休博路73号401室 5281 of 5000
# GET: 杭州市临浦镇-塘郎孙行政村-塘郎孙自然村 5282 of 5000
# GET: 杭州市瓜沥镇明朗行政村东部水果批发市场 5283 of 5000
# GET: 杭州市加州阳光4幢 5284 of 5000
# GET: 杭州萱萱科技有限公司 5285 of 5000
# GET: 浙江省杭州市萧山区义桥镇联三行政村 靠厂区边上 5286 of 5000
# GET: 杭州市萧山区围垦垦区萧山5.2万亩垦区 5287 of 5000
# GET: 杭州华伟兴业印染有限公司 5288 of 5000
# GET: 围垦垦区-杭州萧山种鸡（萧山鸡）有限公司 5289 of 5000
# GET: 杭州市萧山区宁围街道胜坝村43号 5290 of 5000
# GET: 杭州市水利博物馆公司 5291 of 5000
# GET: 浙江省-杭州市-萧山区-楼塔镇-大黄岭行政村-浙江交工集团股份有限公司 5292 of 5000
# GET: 瓜沥镇-单木桥行政村-杭州立川家私有限公司 5293 of 5000
# GET: 杭州市义蓬镇昌北村2组 5294 of 5000
# GET: 杭州市瓜沥镇友谊行政村 5295 of 5000
# GET: 杭州市5.2万亩盈丰垦种 5296 of 5000
# GET: 杭州市宁围街道嘉丰南苑 5297 of 5000
# GET: 杭州市益农镇-益农行政村-益农自然村 5298 of 5000
# GET: 浙江省-杭州市-萧山区-义桥镇-田丰行政村-杭州金盾印务有限公司 5299 of 5000
# GET: 杭州桑莱特木业有限公司 5300 of 5000
# GET: 杭州市河庄街道-闸北行政村-闸北自然村 5301 of 5000
# GET: 杭州传化汇通公路港物流有限公司 5302 of 5000
# GET: 杭州市春光村 5303 of 5000
# GET: 浙江省杭州市萧山区新街街道沿江村1组 5304 of 5000
# GET: 杭州市北干街道塘湾码头 5305 of 5000
# GET: 杭州市瓜沥镇-张神殿行政村 5306 of 5000
# GET: 杭州市新街镇--新街街道-沿江行政村-沿江自然村 5307 of 5000
# GET: 杭州市益农镇-星联行政村 5308 of 5000
# GET: 杭州市河庄街道-新围行政村-新围自然村 5309 of 5000
# GET: 杭州宏松建设有限公司 5310 of 5000
# GET: 浙江省杭州市萧山区临浦镇新河行政村三庄自然村83号 5311 of 5000
# GET: 浙江省杭州市萧山区进化镇墅上王工业区 5312 of 5000
# GET: 浙江省杭州市萧山区进化镇祝家行政村四成 5313 of 5000
# GET: 杭州市瓜沥镇-群谊行政村-群谊自然村 5314 of 5000
# GET: 杭州萧山清和商务酒店 5315 of 5000
# GET: 杭州戈迪装饰材料有限公司 5316 of 5000
# GET: 浙江省杭州市萧山区林浦镇南秀园小区 5317 of 5000
# GET: 杭州奥仁化纤有限公司 5318 of 5000
# GET: 浙江省-杭州市-萧山区-瓜沥镇-渔庄行政村-杭州越翔科纺整理有限公司 5319 of 5000
# GET: 杭州市西河公寓 5320 of 5000
# GET: 进化镇-大汤坞新行政村-杭州市萧山区进化镇人民政府 5321 of 5000
# GET: 杭州市萧山交通局 5322 of 5000
# GET: 杭州市新塘街道-傅楼行政村 5323 of 5000
# GET: 杭州市宁围街道合丰行政村利丰路柏峰珑悦府碧桂园5幢902室 5324 of 5000
# GET: 杭州市宁围镇佳丰南苑商铺 5325 of 5000
# GET: 杭州市萧山区人民政府宁围街道办事处 5326 of 5000
# GET: 杭州淮海纺织厂 5327 of 5000
# GET: 杭州市经济技术开发区-市北社区-建设二路 5328 of 5000
# GET: 杭州镪鑫机械件厂 5329 of 5000
# GET: 杭州顺兴实业有限公司 5330 of 5000
# GET: 杭州市同二自然村 5331 of 5000
# GET: 杭州诗翔科技有限公司 5332 of 5000
# GET: 杭州纪产农业开发有限公司 5333 of 5000
# GET: 浙江省杭州市萧山区义桥镇湘东村新农村56号 5334 of 5000
# GET: 杭州市新湾街道新北桥社区蓝商路 5335 of 5000
# GET: 杭州其门堂蔬菜食品有限公司 5336 of 5000
# GET: 杭州市萧山区城厢街道湖头城村委红馆 5337 of 5000
# GET: 杭州市瓜沥镇-三岔路行政村 5338 of 5000

# %%
# 看看结果
print(addrs[0])
rspss[0].text
# Out:
# 浙江省杭州市萧山区新街街道双圩行政村
# 'showLocation&&showLocation({"status":0,"result":{"location":{"lng":120.35907126489899,"lat":30.217668800819845},"precise":0,"confidence":25,"comprehension":100,"level":"乡镇"}})'

# %%
import json
json.loads( re.search('\((.+)\)', rspss[0].text).group(1) )
# Out:
# {'status': 0,
#  'result': {'location': {'lng': 120.35907126489899, 'lat': 30.217668800819844},
#   'precise': 0,
#   'confidence': 25,
#   'comprehension': 100,
#   'level': '乡镇'}}

# %%
# 我们先用所有地址的经纬全部替换萧山区数据，也就是 xsdf 的中的地址列scope
# 那么第一步我们要先构造 地址：经纬  大字典


''' TODO here '''

import json

addr_lng_dic = dict()

for i in range( len( addrs)):
    try:
        # print(i)
        addr_lng_dic[ addrs[i] ] = json.loads( re.search('\((.+)\)', rspss[i].text).group(1))['result']['location']
    except AttributeError:
        print('error at', i, '>>', addrs[i])
    except KeyError:
        print('no_res at', i, '>>', addrs[i])

# addr_lng_dic

# 我们可以看到，这一步也是有一些各类原因下没有相应的地点的；为了那个啥，我们在底下走替换这一步时，把这些地点筛去；直接扔掉即可
# Out:
# error at 248 >> 9#商场（联邦美发）
# no_res at 2975 >> 浙江省-杭州市-萧山区-楼塔镇-大黄岭行政村-浙江交工集团股份有限公司浙江省杭州市萧山区楼塔镇大黄岭行政村水阁
# no_res at 3419 >> 浙江省-杭州市-萧山区-经济技术开发区-市北社区-杭州萧山经济技术开发区国有资产经营有限公司
# no_res at 4835 >> 浙江省-杭州市-萧山区-新街街道-山末址行政村-绍兴市柯桥区杭绍城际轨道交通建设投资有限公司
# no_res at 4850 >> 浙江省-杭州市-萧山区-河庄街道-建一行政村-中国水利水电第十四工程局有限公司杭州大江东基础设施项目经理部

# %%
# 接下来就是把T里面的物理地址全部替换为经纬，我们用新的变量名 lng_t

# 这里注意由于有空项，不要用集合表达式为好，再细分一次操作

lng_t = list()

# for addrset in t:
#     try:
#         lng_t.append(  
#             { (addr_lng_dic[_]['lng'], addr_lng_dic[_]['lat']) for _ in addrset } 
#         )
#     except KeyError:
#         print(1)


for addrset in t:
    tmpl = set()
    for addr in addrset:
        try:
            tmpl.add(  (addr_lng_dic[addr]['lng'], addr_lng_dic[addr]['lat']) )
        except KeyError:
            pass
    lng_t.append( tmpl)

lng_t[:10]
# Out:
# [{(120.13327606648856, 30.076105166336152),
#   (120.19457409889512, 30.068892958174597)},
#  {(120.21551180372168, 30.25308298169347),
#   (120.45334222986314, 30.31605196581798),
#   (120.46848366958999, 30.338653921723363)},
#  {(120.43070641860562, 30.269104550435205),
#   (120.44659820124699, 30.286079095817154)},
#  {(120.26905189008298, 30.220367063336294),
#   (120.27011278889027, 30.221318946224738),
#   (120.28698770762414, 30.21649782989135)},
#  {(120.48608816061838, 30.23467467379749)},
#  {(120.1837189023498, 30.07061160179425),
#   (120.20862898690424, 30.06612213640747)},
#  {(120.43070641860562, 30.269104550435205),
#   (120.44659820124699, 30.286079095817154)},
#  {(120.29232924149164, 30.24765459914221),
#   (120.29830916155967, 30.202053852930828)},
#  {(120.26002041631622, 30.15861032664578)},
#  {(120.17029221106178, 30.005080592317373),
#   (120.1989063568781, 30.021745735100378),
#   (120.20626707222685, 30.01713293986793)}]

# %%
# 好了 替换吧
len(lng_t) - len(t) == 0
xsdf.scope = lng_t

# %%
# 全部走完之后，我们把位置和duration取出来，然后做一个累加，画热力图
# 我们先取它的一个视图，复制一份
pic_df = xsdf.loc[:, ('scope', 'duration')].copy()
pic_df
# Out:
#                                                   scope  \
# 0     {(120.13327606648856, 30.076105166336152), (12...
# 1     {(120.21551180372168, 30.25308298169347), (120...
# 2     {(120.43070641860562, 30.269104550435205), (12...
# 3     {(120.28698770762414, 30.21649782989135), (120...
# 4             {(120.48608816061838, 30.23467467379749)}
# ...                                                 ...
# 2835         {(120.13709483626876, 29.884171982013306)}
# 2836           {(120.2606888133609, 29.96992060064806)}
# 2837         {(120.25207346679166, 30.208310245168462)}
# 2838         {(120.46626229660626, 30.196281582758512)}
# 2839  {(120.31723651165493, 30.160613535797303), (12...
#
#                        duration
# 0     0 days 02:10:00.000000000
# 1     0 days 04:26:00.000000000
# 2     0 days 04:05:00.000000000
# 3     0 days 01:39:00.000000000
# 4     0 days 03:35:00.000000000
# ...                         ...
# 2835  0 days 01:15:00.000000000
# 2836  0 days 01:32:00.000000000
# 2837  0 days 02:00:00.000000000
# 2838  0 days 02:34:00.000000000
# 2839  0 days 03:06:00.000000000
#
# [2787 rows x 2 columns]

# %%
# 由于这个duration是上个df里减来的（我也忘了处理过程了）；我们给它换成分钟值, 因为懒 所以我们就自己写个字符串解析了 numpy的timedelta要花时间看

def timedura_to_min( duration_string):
    """
        such as  `0 days 02:10:00.0000000` -> 0*24*60 + 2*60 +10
    """
    res = int(0)
    gs = duration_string.split(' ')
    
    res += int(gs[0]) * 24 * 60
    ts = gs[2].split(':')
    res += int(ts[0]) * 60
    res += int(ts[1])

    return res
    pass

# 先写个方法

# %%
# 计算下 替换回去
pic_df.duration =  [timedura_to_min( _) for _ in pic_df.duration.values]

# %%
# 好了！ 这就是我们想要的结果； 接下来我们再划分， 把相同的点的值相加
# 到这一步其实可以存一下当前的df；但是我们短期内是不会断开这个文件的连接的
pic_df
# Out:
#                                                   scope  duration
# 0     {(120.13327606648856, 30.076105166336152), (12...       130
# 1     {(120.21551180372168, 30.25308298169347), (120...       266
# 2     {(120.43070641860562, 30.269104550435205), (12...       245
# 3     {(120.28698770762414, 30.21649782989135), (120...        99
# 4             {(120.48608816061838, 30.23467467379749)}       215
# ...                                                 ...       ...
# 2835         {(120.13709483626876, 29.884171982013306)}        75
# 2836           {(120.2606888133609, 29.96992060064806)}        92
# 2837         {(120.25207346679166, 30.208310245168462)}       120
# 2838         {(120.46626229660626, 30.196281582758512)}       154
# 2839  {(120.31723651165493, 30.160613535797303), (12...       186
#
# [2787 rows x 2 columns]

# %%
# next(pic_df.iterrows())[1][x]  x项0为scope 1为duration

scope_dura_dic = dict()

for row in pic_df.iterrows():
    for s in row[1][0]:
        if s in scope_dura_dic:
            scope_dura_dic[s] += row[1][1]
        else:
            scope_dura_dic[s] = row[1][1]

print( len(scope_dura_dic) )
print( len(addr_lng_dic) )
# Out:
# 2176
# 5333

# %%
# 从上面我们可以看到，5300多个地点其实只投射到了2200个经纬，
# 这有一部分原因是因为地址解析不准确，但也有一部分原因是一些地点本来就在一个经纬坐标上
# 解析不准确的原因一是因为我们的信息处理方法有垃圾之处，在这点是可以进行改进的

# 那么不多说，我们做高德的数据集; 高德需要四个数据项： lat lng latlng count； latlng这个项就是前俩项并成一个元组，不知道为啥要这样， count就是热力值


gd_df = pd.DataFrame(scope_dura_dic.items())
gd_df.columns = ['经纬度','count']
gd_df
# Out:
#                                            经纬度  count
# 0     (120.13327606648856, 30.076105166336152)   3249
# 1     (120.19457409889512, 30.068892958174597)    130
# 2      (120.21551180372168, 30.25308298169347)  78562
# 3     (120.46848366958999, 30.338653921723363)  37299
# 4      (120.45334222986314, 30.31605196581798)   1784
# ...                                        ...    ...
# 2171  (120.32808872204362, 30.173386241495713)    130
# 2172   (120.19348032210617, 30.08119950749933)    420
# 2173   (120.30455112722629, 30.17623359886891)    117
# 2174  (120.25207346679166, 30.208310245168462)    120
# 2175   (120.3537166454151, 30.161149566114382)    186
#
# [2176 rows x 2 columns]

# %%
# 高德不能接受元组，我们把经纬转成字符串。
gd_df['经纬度'] = [ str(_[0]) + ", " + str(_[1]) for _ in gd_df['经纬度'].values]

# %%
gd_df.index = gd_df['经纬度']
gd_df.loc[:, 'count'].to_csv('gddf')

# %%
# 至此已经走完第一个demo了；我们把gddf放入高德lab中即可；
# 为了防止反复使用api我们可以用pickle存一下rspss变量这个响应列表；当然，也不是很有必要；

# 最后是一些接下来的工作： 要保存现场；然后回顾一下以上的处理过程，
#   最好是从最原始的df开始重新温习一遍全部的处理流程。然后针对各个中段写一个比较好的代码以便复用；
#   这里立个 TODO 吧；明天来做这个工作； 
#   
#   by 7.20 night
